# %%
#изучить работу с пандасом, научиться работать с таблицами
import pandas as pd

terra = pd.read_csv("Terraria DPS_TV1.4.4.9_V1 - Sheet1.csv")#Вводим данные в программу

terra.head()#Выводим данные
# Out:
#          NAME  CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 0      Zenith  Melee    Post-Moonlord                 4800
# 1  Last Prism   Mage    Post-Moonlord                 3657
# 2  Star Wrath  Melee    Post-Moonlord                 2700
# 3   Terrarian  Melee    Post-Moonlord                 2200
# 4    Mewomere  Melee    Post-Moonlord                 2100
#
#    DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# 0             13000.0                                    NaN
# 1              1142.0                                    NaN
# 2              5800.0                                 1500.0
# 3              4600.0                                  700.0
# 4              6400.0                                 1300.0
#
#    DPS (MULTI TARGET + PROYECTILE ONLY)   OBSERVATIONS
# 0                                   NaN            NaN
# 1                                   NaN  Fully charged
# 2                                3700.0            NaN
# ...

# %%
terra.shape#количесво строчек\столбцов
# Out:
# (395, 8)

# %%
terra.columns#вывести все названия столбцов
# Out:
# Index(['NAME', 'CLASS', 'GAME PROGRESSION', 'DPS (SINGLE TARGET)',
#        'DPS (MULTI TARGET)', 'DPS (SINGLE TARGET + PROYECTILE ONLY)',
#        'DPS (MULTI TARGET + PROYECTILE ONLY)', 'OBSERVATIONS'],
#       dtype='object')

# %%
terra["DPS (SINGLE TARGET)"].unique()#Уникальные значения
# Out:
# array([4800, 3657, 2700, 2200, 2100, 1974, 1709, 1500, 1467, 1300, 1256,
#        1254, 1210, 1200, 1100, 1094, 1067, 1056,  976,  949,  914,  800,
#         779,  752,  750,  742,  720,  700,  691,  650,  635,  633,  614,
#         613,  600,  599,  590,  580,  564,  553,  530,  520,  512,  507,
#         500,  460,  450,  444,  431,  428,  425,  420,  410,  406,  400,
#         398,  385,  383,  365,  363,  350,  333,  330,  320,  315,  312,
#         300,  292,  286,  282,  281,  280,  272,  271,  270,  260,  254,
#         250,  242,  240,  237,  223,  220,  218,  210,  206,  203,  202,
#         201,  200,  197,  190,  182,  180,  172,  170,  165,  164,  163,
#         162,  161,  160,  152,  151,  150,  145,  140,  132,  130,  128,
#         120,  117,  116,  113,  112,  110,  107,  104,  102,  100,   95,
#          90,   86,   85,   80,   76,   75,   72,   71,   70,   65,   64,
#          63,   62,   60,   56,   55,   52,   50,   49,   48,   45,   44,
# ...

# %%
terra.sort_values(by='DPS (SINGLE TARGET)')#отсортировать по урону в секунду по одной цели
# Out:
#                    NAME     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 394  Lightning Aura Rod  Summoner         Pre-Boss                    8
# 393         Flinx Staff  Summoner         Pre-Boss                    8
# 392      Flameburst Rod  Summoner         Pre-Boss                    8
# 391         Finch Staff  Summoner         Pre-Boss                   10
# 390         Paper Plane    Ranger         Pre-Boss                   14
# ..                  ...       ...              ...                  ...
# 4              Mewomere     Melee    Post-Moonlord                 2100
# 3             Terrarian     Melee    Post-Moonlord                 2200
# 2            Star Wrath     Melee    Post-Moonlord                 2700
# 1            Last Prism      Mage    Post-Moonlord                 3657
# 0                Zenith     Melee    Post-Moonlord                 4800
#
#      DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# ...

# %%
terra.drop(columns= ["OBSERVATIONS"])#убрать колонку с пояснениями
# Out:
#                    NAME     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 0                Zenith     Melee    Post-Moonlord                 4800
# 1            Last Prism      Mage    Post-Moonlord                 3657
# 2            Star Wrath     Melee    Post-Moonlord                 2700
# 3             Terrarian     Melee    Post-Moonlord                 2200
# 4              Mewomere     Melee    Post-Moonlord                 2100
# ..                  ...       ...              ...                  ...
# 390         Paper Plane    Ranger         Pre-Boss                   14
# 391         Finch Staff  Summoner         Pre-Boss                   10
# 392      Flameburst Rod  Summoner         Pre-Boss                    8
# 393         Flinx Staff  Summoner         Pre-Boss                    8
# 394  Lightning Aura Rod  Summoner         Pre-Boss                    8
#
#      DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# ...

# %%
terr=terra.replace({"DPS (SINGLE TARGET + PROYECTILE ONLY)":np.NaN},"don't have projectiles")#заменить отсутствие значения фразой, описывающей причину её отсутствия
terr.head#Выводим данные
# Out:
# <bound method NDFrame.head of                    NAME     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 0                Zenith     Melee    Post-Moonlord                 4800
# 1            Last Prism      Mage    Post-Moonlord                 3657
# 2            Star Wrath     Melee    Post-Moonlord                 2700
# 3             Terrarian     Melee    Post-Moonlord                 2200
# 4              Mewomere     Melee    Post-Moonlord                 2100
# ..                  ...       ...              ...                  ...
# 390         Paper Plane    Ranger         Pre-Boss                   14
# 391         Finch Staff  Summoner         Pre-Boss                   10
# 392      Flameburst Rod  Summoner         Pre-Boss                    8
# 393         Flinx Staff  Summoner         Pre-Boss                    8
# 394  Lightning Aura Rod  Summoner         Pre-Boss                    8
#
#      DPS (MULTI TARGET) DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# ...

# %%
terra.drop_duplicates ()# Убрать все дупликаты
# Out:
#                    NAME     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 0                Zenith     Melee    Post-Moonlord                 4800
# 1            Last Prism      Mage    Post-Moonlord                 3657
# 2            Star Wrath     Melee    Post-Moonlord                 2700
# 3             Terrarian     Melee    Post-Moonlord                 2200
# 4              Mewomere     Melee    Post-Moonlord                 2100
# ..                  ...       ...              ...                  ...
# 390         Paper Plane    Ranger         Pre-Boss                   14
# 391         Finch Staff  Summoner         Pre-Boss                   10
# 392      Flameburst Rod  Summoner         Pre-Boss                    8
# 393         Flinx Staff  Summoner         Pre-Boss                    8
# 394  Lightning Aura Rod  Summoner         Pre-Boss                    8
#
#      DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# ...

# %%
terra.info()#вывести информацию по таблицы
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 8 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   NAME                                   395 non-null    object
#  1   CLASS                                  395 non-null    object
#  2   GAME PROGRESSION                       395 non-null    object
#  3   DPS (SINGLE TARGET)                    395 non-null    int64
#  4   DPS (MULTI TARGET)                     308 non-null    float64
#  5   DPS (SINGLE TARGET + PROYECTILE ONLY)  25 non-null     float64
#  6   DPS (MULTI TARGET + PROYECTILE ONLY)   19 non-null     float64
#  7   OBSERVATIONS                           140 non-null    object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 24.8+ KB

# %%
terra.describe()#вывести информацию через describe
# Out:
#        DPS (SINGLE TARGET)  DPS (MULTI TARGET)  \
# count           395.000000          308.000000
# mean            262.273418          651.107143
# std             437.778258         1103.783469
# min               8.000000           17.000000
# 25%              58.000000          147.500000
# 50%             130.000000          346.000000
# 75%             289.000000          769.500000
# max            4800.000000        13000.000000
#
#        DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# count                              25.000000
# mean                              348.600000
# std                               380.502738
# min                                30.000000
# 25%                                80.000000
# 50%                               250.000000
# 75%                               500.000000
# max                              1500.000000
#
#        DPS (MULTI TARGET + PROYECTILE ONLY)
# count                             19.000000
# ...

# %%
summoner = terra.loc[terra["CLASS"] == "Summoner"]#вывести данные по оружию только для призывателя
summoner.head()#Выводим данные
# Out:
#                      NAME     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 41  Stardust Dragon Staff  Summoner     Post-Cultist                  580
# 60           Kaleidoscope  Summoner         Post-EoL                  420
# 71           Dark Harvest  Summoner    Post-Plantera                  350
# 73  Rainbow Crystal Staff  Summoner    Post-Moonlord                  350
# 93           Morning Star  Summoner    Post-Plantera                  300
#
#     DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# 41              1700.0                                    NaN
# 60              1200.0                                    NaN
# 71               950.0                                    NaN
# 73              1000.0                                    NaN
# 93               850.0                                    NaN
#
#     DPS (MULTI TARGET + PROYECTILE ONLY) OBSERVATIONS
# 41                                   NaN          NaN
# ...

# %% [markdown]
# вывод
# был изучен пандас и работа с таблицами
